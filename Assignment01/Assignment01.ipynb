# %% [markdown]
# #Writer: Junhyuck Woo <br>
# #Date: Mar 28, 2020
# <hr>

# %% [markdown]
# Test the coding

# %%
print("hello world~!")
# Out:
# hello world~!

# %% [markdown]
# Test the LaTeX - Copied from the assignment guideline

# %% [markdown]
# $ J(θ)=\frac{1}{2m}\sum_{i=1}^{m}​(hθ​(x(i))−y(i))^2$

# %% [markdown]
# $$ J(θ)=\frac{1}{2m}\sum_{i=1}^{m}​(hθ​(x(i))−y(i))^2$$
